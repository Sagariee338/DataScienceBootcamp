# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagariee338/DataScienceBootcamp/blob/main/Qualitative_Variable_and_Contingency_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import scipy.stats as stats

# %%
df = pd.read_csv("/content/Que.csv")
df
# Out:
#      Name Nationality     Sex   Age Handedness
# 0   chris       India  Female  34.0      Right
# 1    agee       India  Female  45.0      Right
# 2   fsads       India    Male  56.0      Right
# 3    aman   Bangadesh    Male  21.0       Left
# 4   ggeng   Bangadesh  Female  55.0       Left
# 5     tom     England    Male   NaN       Left
# 6     gsm         USA    Male  56.0       Left
# 7     vok         USA    Male  43.0       Left
# 8     bon         USA    Male  24.0      Right
# 9     jim         USA  Female  32.0      Right
# 10   alex       China  Female  67.0       Left

# %%
pd.crosstab(df.Nationality,df.Handedness)
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh       2      0
# China           1      0
# England         1      0
# India           0      3
# USA             2      2

# %%
pd.crosstab(df.Nationality,df.Handedness)
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh       2      0
# China           1      0
# England         1      0
# India           0      3
# USA             2      2

# %%
pd.crosstab(df.Sex,df.Handedness)
# Out:
# Handedness  Left  Right
# Sex
# Female         2      3
# Male           4      2

# %%
df_table= pd.crosstab(df['Sex'],df['Handedness'])
print(df_table)
# Out:
# Handedness  Left  Right
# Sex
# Female         2      3
# Male           4      2

# %%
df.values
# Out:
# array([['chris', 'India', 'Female', 34.0, 'Right'],
#        ['agee', 'India', 'Female', 45.0, 'Right'],
#        ['fsads', 'India', 'Male', 56.0, 'Right'],
#        ['aman', 'Bangadesh', 'Male', 21.0, 'Left'],
#        ['ggeng', 'Bangadesh', 'Female', 55.0, 'Left'],
#        ['tom', 'England', 'Male', nan, 'Left'],
#        ['gsm', 'USA', 'Male', 56.0, 'Left'],
#        ['vok', 'USA', 'Male', 43.0, 'Left'],
#        ['bon', 'USA', 'Male', 24.0, 'Right'],
#        ['jim', 'USA', 'Female', 32.0, 'Right'],
#        ['alex', 'China', 'Female', 67.0, 'Left']], dtype=object)

# %%
#observed values
observed_values =df_table.values
print("observed values :-\n",observed_values)
# Out:
# observed values :-
#  [[2 3]
#  [4 2]]

# %%
val=stats.chi2_contingency(df_table)
val
# Out:
# Chi2ContingencyResult(statistic=0.07638888888888876, pvalue=0.782252069887464, dof=1, expected_freq=array([[2.72727273, 2.27272727],
#        [3.27272727, 2.72727273]]))

# %%
Expected_values= val[3]

# %%
no_of_rows =len(df_table.iloc[0:2,0])
no_of_columns=len(df.iloc[0,0:2])
ddof=(no_of_rows-1)*(no_of_columns-1)
print("Degree of freedom:",ddof)
alpha= 0.05
# Out:
# Degree of freedom: 1

# %%
from scipy.stats import chi2
chi_square=sum([(o-e)**2./e for o,e in zip(observed_values,Expected_values)])
chi_square_statistic=chi_square[0]+chi_square[1]

# %%
print("chi-square statistic:-",chi_square_statistic)
# Out:
# chi-square statistic:- 0.7822222222222217

# %%
critical_value=chi2.ppf(q=1-alpha,df=ddof)
print('critical_value:',critical_value)
# Out:
# critical_value: 3.841458820694124

# %%
#p-value
p_value=1-chi2.cdf(x=chi_square_statistic,df=ddof)
print('p-value:',p_value)
print('Significance level: ',alpha)
print('Degree of Freedom: ',ddof)
print('p-value:',p_value)
# Out:
# p-value: 0.37646236576763803
# Significance level:  0.05
# Degree of Freedom:  1
# p-value: 0.37646236576763803
