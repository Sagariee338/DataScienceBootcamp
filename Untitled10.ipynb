# %%
sum = 0
for i in range(10):
  sum = sum + i
  print(sum)
# Out:
# 0
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Euro2012TEAM (1).csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(3)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 0                     0  ...          13                 81.3%         41
# 1                     0  ...           9                 60.1%         53
# 2                     0  ...          10                 66.7%         25
#
# ...

# %%
df.loc[0:6]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# ...

# %%
df.loc[0,:]
# Out:
# Team                          Croatia
# Goals                               4
# Shots on target                    13
# Shots off target                   12
# Shooting Accuracy               51.9%
# % Goals-to-shots                16.0%
# Total shots (inc. Blocked)         32
# Hit Woodwork                        0
# Penalty goals                       0
# Penalties not scored                0
# Headed goals                        2
# Passes                           1076
# Passes completed                  828
# Passing Accuracy                76.9%
# Touches                          1706
# Crosses                            60
# Dribbles                           42
# Corners Taken                      14
# Tackles                            49
# Clearances                         83
# Interceptions                      56
# Clearances off line               NaN
# Clean Sheets                        0
# Blocks                             10
# Goals conceded                      3
# ...

# %%
df.loc[[0,1,2,3,4],:]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
df.loc[0:4,:]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
df.iloc[0:4,:]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 0                     0  ...          13                 81.3%         41
# ...

# %%
df.loc[:,'Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
df.loc[: ,'Team':'Players Used']
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
df.loc[df.Goals=='Penalty goals']
# Out:
# Empty DataFrame
# Columns: [Team, Goals, Shots on target, Shots off target, Shooting Accuracy, % Goals-to-shots, Total shots (inc. Blocked), Hit Woodwork, Penalty goals, Penalties not scored, Headed goals, Passes, Passes completed, Passing Accuracy, Touches, Crosses, Dribbles, Corners Taken, Tackles, Clearances, Interceptions, Clearances off line, Clean Sheets, Blocks, Goals conceded, Saves made, Saves-to-shots ratio, Fouls Won, Fouls Conceded, Offsides, Yellow Cards, Red Cards, Subs on, Subs off, Players Used]
# Index: []
#
# [0 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
df.iloc[:,0:2]
# Out:
#                    Team  Goals
# 0               Croatia      4
# 1        Czech Republic      4
# 2               Denmark      4
# 3               England      5
# 4                France      3
# 5               Germany     10
# 6                Greece      5
# 7                 Italy      6
# 8           Netherlands      2
# 9                Poland      2
# 10             Portugal      6
# 11  Republic of Ireland      1
# 12               Russia      5
# 13                Spain     12
# 14               Sweden      5
# 15              Ukraine      2

# %%
df.'Goals.sum()
# Out:
#   File "<ipython-input-38-3477ae6bacb7>", line 1
#     df.'Goals.sum()
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df.iloc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-69a819a96b55> in <cell line: 1>()
# ----> 1 df.iloc
#
# NameError: name 'df' is not defined

# %%
from numpy import*


arr=array([1,2,3,4,5.0],int)
print(arr)
print(dtype)
# Out:
# [1 2 3 4 5]
# <class 'numpy.dtype'>

# %%
df.c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-69a819a96b55> in <cell line: 1>()
# ----> 1 df.iloc
#
# NameError: name 'df' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b666bf274d0a> in <cell line: 1>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df1= pd.DataFrame()
print(df1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# append columns
df1['ID'] = [1,2,3]
df1['Emp'] = ("A","B","C")
df1['Salary'] = (1000,2000,3000)
df1["Exp"]= [3,4,5]
print(df1)
# Out:
#    ID Emp  Salary  Exp
# 0   1   A    1000    3
# 1   2   B    2000    4
# 2   3   C    3000    5

# %%
df3 = pd.DataFrame(columns = ['ID','EMP','SALARY','EXP'] ,index=[1,2,3,4])
df3
# Out:
#     ID  EMP SALARY  EXP
# 1  NaN  NaN    NaN  NaN
# 2  NaN  NaN    NaN  NaN
# 3  NaN  NaN    NaN  NaN
# 4  NaN  NaN    NaN  NaN

# %%
df3['EMP']=['simon','chris','nemo','nick']
df3
# Out:
#     ID    EMP SALARY  EXP
# 1  NaN  simon    NaN  NaN
# 2  NaN  chris    NaN  NaN
# 3  NaN   nemo    NaN  NaN
# 4  NaN   nick    NaN  NaN

# %%
df3['ID'] = [1,2,3,4]
df3['SALARY'] = (1000,2000,3000,400)
df3["EXP"]= [3,4,5,5]
df3
# Out:
#    ID    EMP  SALARY  EXP  Salary  Exp
# 1   1  simon    1000    3    1000    3
# 2   2  chris    2000    4    2000    4
# 3   3   nemo    3000    5    3000    5
# 4   4   nick     400    5     400    5

# %%
df4=pd.DataFrame([[1,2],[3,4]],columns=list("AB"),index=('a','b'))
df4
# Out:
#    A  B
# a  1  2
# b  3  4
